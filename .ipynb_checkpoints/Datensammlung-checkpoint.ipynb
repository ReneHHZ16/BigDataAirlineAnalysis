# %%
import numpy as np
import pandas as pd
# Importieren der Standard Bibliotheken, immer wenn Error name not found dann muss die entsprechende Bibliothek noch geladen werden

# %%
data = pd.read_csv('Daten/1987.csv/1987.csv')
# Einlesen der Flugdaten des jeweiligen Landes (Text vor dem = bedeutet vergebener Name für die Datei der im Notebook verwendet wird
)

# %%
flight_1987 = data[['Year','UniqueCarrier', 'Dest', 'Origin', 'Cancelled', 'ArrDelay', 'DepDelay']]
flight_1987.
# Darstellung aller Flüge aus dem Jahr 1987, gefiltert mit Informationen über Jahr, Airline bzw. Unique Carrier, Destination, Origin, Canelled, sowie Arr and Dep Delay
# Out:
#          Year UniqueCarrier Dest Origin  Cancelled  ArrDelay  DepDelay
# 0        1987            PS  SFO    SAN          0      23.0      11.0
# 1        1987            PS  SFO    SAN          0      14.0      -1.0
# 2        1987            PS  SFO    SAN          0      29.0      11.0
# 3        1987            PS  SFO    SAN          0      -2.0      -1.0
# 4        1987            PS  SFO    SAN          0      33.0      19.0
# 5        1987            PS  SFO    SAN          0      -1.0      -2.0
# 6        1987            PS  SFO    SAN          0       3.0      -2.0
# 7        1987            PS  SFO    SAN          0      13.0       1.0
# 8        1987            PS  SFO    SAN          0      19.0      14.0
# 9        1987            PS  SFO    SAN          0       2.0      -1.0
# 10       1987            PS  SFO    SAN          0      15.0       5.0
# 11       1987            PS  SFO    SAN          0      24.0      16.0
# ...

# %%
data2 = pd.read_csv('Daten/carriers.csv')
# Einlesen der Codes für die Unique Carrier

# %%
data2 
# Übersicht der Carrier Codes
# Out:
#         Code                                   Description
# 0        02Q                                 Titan Airways
# 1        04Q                            Tradewind Aviation
# 2        05Q                           Comlux Aviation, AG
# 3        06Q                 Master Top Linhas Aereas Ltd.
# 4        07Q                           Flair Airlines Ltd.
# 5        09Q                                Swift Air, LLC
# 6        0BQ                                           DCA
# 7        0CQ                          ACM AIR CHARTER GmbH
# 8        0FQ          Maine Aviation Aircraft Charter, LLC
# 9        0GQ  Inter Island Airways, d/b/a Inter Island Air
# 10       0HQ       Polar Airlines de Mexico d/b/a Nova Air
# 11        0J                                    JetClub AG
# 12       0JQ                               Vision Airlines
# 13       0KQ                Mokulele Flight Services, Inc.
# 14       0LQ                             Metropix UK, LLP.
# ...

# %%
airports = pd.read_csv('Daten/airports.csv')
# Einlesen der Daten über die Airport Codes

# %%
airports
# Übersicht der Airport Codes
# Out:
#      iata                       airport                city state  \
# 0     00M                      Thigpen          Bay Springs    MS
# 1     00R          Livingston Municipal          Livingston    TX
# 2     00V                   Meadow Lake    Colorado Springs    CO
# 3     01G                  Perry-Warsaw               Perry    NY
# 4     01J              Hilliard Airpark            Hilliard    FL
# 5     01M             Tishomingo County             Belmont    MS
# 6     02A                   Gragg-Wade              Clanton    AL
# 7     02C                       Capitol          Brookfield    WI
# 8     02G             Columbiana County      East Liverpool    OH
# 9     03D              Memphis Memorial             Memphis    MO
# 10    04M                Calhoun County           Pittsboro    MS
# 11    04Y              Hawley Municipal              Hawley    MN
# 12    05C        Griffith-Merrillville             Griffith    IN
# ...

# %%
insolvent_airlines = pd.read_csv('Daten/Insolvente_Airlines.csv', encoding='ISO-8859-1', sep=';')
# Einlesen der selbsterstellten csv Datei über die insolventen Airlines, bei coding Problemen, ISO Code und Seperator (kann in Text Editor herausgelesen werden) eingeben

# %%
insolvent_airlines
#Ausgabe der Tabelle

insolvent_airlines_filtered = insolvent_airlines [(insolvent_airlines['Insolvency'] >= 1998) & (insolvent_airlines['Insolvency'] <=2008) & (insolvent_airlines ['Period']>= 10)]
#Filtern der Tabelle nach Bedinungen: Gründung muss nach 1998 liegen, Insolvenz darf nicht vor 2008 passiert sein, Zeitspanne zwischen Gründung und Insolvez muss mindestens 10 Jahre betragen

# %%
Carrier_Codes = insolvent_airlines_filtered['Code']
#Filtern der Airline Tabelle als Liste die nur die Airline Codes ausgibt, Namensvergabe für die Liste als Carrier_Codes

# %%
Carrier_Codes
#Darstellung der erstellten Liste
# Out:
# 9     GR
# 12    MG
# 13    TZ
# 14    AQ
# 18    HP
# 25    DH
# 57    TW
# 58    FF
# 76    OE
# Name: Code, dtype: object

# %%
insolvent_airlines_flights_1987=flight_1987[flight_1987['UniqueCarrier'].isin(Carrier_Codes)]
#Verknüpfen der gefliterten Flugtabelle aus dem entsprechenden Jahr mit der Liste der anzuzeigenden Airline Codes mit dem Befehl is in

# %%
insolvent_airlines_flights_1987
#Darstellung der Flugliste nur für die Airlines deren Code in der Carrier_Codes Liste vorkommt
# Out:
#          Year UniqueCarrier Dest Origin  Cancelled  ArrDelay  DepDelay
# 13507    1987            TW  STL    JFK          0     -10.0       4.0
# 13508    1987            TW  STL    JFK          0      -2.0      -2.0
# 13509    1987            TW  STL    JFK          0       9.0      16.0
# 13510    1987            TW  STL    JFK          0     -13.0       0.0
# 13511    1987            TW  STL    JFK          0     -15.0       0.0
# 13512    1987            TW  STL    JFK          0     -22.0      -1.0
# 13513    1987            TW  STL    JFK          0     -15.0      -1.0
# 13514    1987            TW  STL    JFK          0      -2.0       0.0
# 13515    1987            TW  STL    JFK          0      -2.0      -1.0
# 13516    1987            TW  STL    JFK          0       4.0      -2.0
# 13517    1987            TW  STL    JFK          0     -11.0      -2.0
# 13518    1987            TW  STL    JFK          0     -11.0      -2.0
# ...

# %%
insolvent_airlines = pd.read_csv('', encoding='ISO-8859-1', sep=';')
insolvent_airlines_filtered = insolvent_airlines [(insolvent_airlines['Insolvency'] >= 1998) & (insolvent_airlines['Insolvency'] <=2008) & (insolvent_airlines ['Period']>= 10)]
Carrier_Codes = insolvent_airlines_filtered['Code']

#pre-schleife um die Airline Codes der gewünschten Airlines (Gründungs und InsolvenzJahr etc) als CodeListe auszugeben

# %%
import os
for file in os.listdir('Daten/ent/'):
    if file.endswith('.csv') and (int(os.path.splitext(file)[0]) >2000):
        #print('pickle/'+os.path.splitext(file)[0]+'.pkl')
        data = pd.read_csv('Daten/ent/'+file, encoding='ISO-8859-1')
        df_flight = data[['Year','UniqueCarrier', 'Dest', 'Origin', 'Cancelled', 'ArrDelay', 'DepDelay']]
        insolvent_airlines_flights=df_flight[df_flight['UniqueCarrier'].isin(Carrier_Codes)]
        insolvent_airlines_flights.to_pickle('pickle/'+os.path.splitext(file)[0]+'.pkl')
        print('Daten/ent/'+file+'..... geladen.')
        
#Vollständige Schleife um alle Daten im entsprechenden Ordner (Daten Pickle ...) einzulesen und nach oben beschriebenen Bedingungen zu filtern und wieder auszugeben
# Out:
# Daten/ent/2001.csv..... geladen.
# Daten/ent/2002.csv..... geladen.
# D:\Benutzer-Profile\kurmannr\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Daten/ent/2003.csv..... geladen.
# Daten/ent/2004.csv..... geladen.
# Daten/ent/2005.csv..... geladen.
# Daten/ent/2006.csv..... geladen.
# Daten/ent/2007.csv..... geladen.
# Daten/ent/2008.csv..... geladen.
